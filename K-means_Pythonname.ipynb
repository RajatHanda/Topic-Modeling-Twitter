# %%
import numpy as np
import sklearn.cluster
import distance
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
df=pd.read_csv("/Users/rajathanda/Downloads/eng1.csv",encoding = 'ISO-8859-1')

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=50, init='k-means++', n_init=10)

# %%
df.head()
# Out:
#       user_id Gender.Labeled     name  surname
# 0  1007363503              f    Nkehe     Bita
# 1   100925545              m  Richard      Hue
# 2  1010066696              m     Manu   Lohiya
# 3  1013685540              m     Seth  Bocknek
# 4     1014851              f      Amy  Hendrix

# %%
words=df["surname"].tolist()
words = np.asarray(words)

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(words)

# %%
true_k = 1000
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
km=model.fit(X)
 
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print
# Out:
# Top terms per cluster:
# Cluster 0:
#  steel
#  öavdó
#  glaser
#  green
#  gray
#  graham
#  gov
#  goulet
#  gotopo
#  gordon
# Cluster 1:
#  nan
#  öavdó
#  garrick
#  green
#  gray
#  graham
#  gov
#  goulet
#  gotopo
#  gordon
# Cluster 2:
#  öavdó
#  harburn
#  green
#  gray
#  graham
#  gov
#  goulet
#  gotopo
#  gordon
#  gopalan
# Cluster 3:
#  systems
#  grison
#  green
#  gray
#  graham
#  gov
#  goulet
#  gotopo
#  gordon
#  gopalan
# Cluster 4:
#  jackson
#  öavdó
#  giza
#  gray
#  graham
#  gov
#  goulet
#  gotopo
#  gordon
#  gopalan
# Cluster 5:
#  tech
#  öavdó
#  grison
#  green
#  gray
#  graham
#  gov
#  goulet
#  gotopo
#  gordon
# Cluster 6:
#  106
#  harburn
#  green
#  gray
#  graham
#  gov
#  goulet
#  gotopo
#  gordon
#  gopalan
# Cluster 7:
#  ruiz
#  öavdó
#  grill
#  gray
#  graham
#  gov
#  goulet
#  gotopo
#  gordon
#  gopalan
# Cluster 8:
#  jobs
#  öavdó
#  grill
#  gray
#  graham
#  gov
#  goulet
#  gotopo
#  gordon
#  gopalan
# Cluster 9:
# ...

# %%
predict=km.predict(X)

# %%
predict[1:300]
# Out:
# array([ 3,  3,  3,  3,  3,  3,  3,  3,  3, 29,  3,  3,  3,  3, 45,  3,  3,
#         3, 24,  3,  3,  3,  3,  3, 17,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3, 44,  3,
#         3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3, 15,  3,
#         3,  3, 15,  3,  3, 16,  3, 44,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3,  3,  3,  3, 41,  3,  3,  3,  3,  3,  3,  3,  3,  3, 28,
#         3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3, 28,  3,
#         3,  3,  3,  3,  3,  3,  3,  3, 31,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3,  3,  3,  3, 22,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3,  3,  3,  7,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#         3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
# ...

# %%
df['SurName_Cluster_1000'] = pd.Series(predict, index=df.index)

# %%
df.tail()
# Out:
#         user_id Gender.Labeled     name      surname  Name_Cluster_50  \
# 1429  976184082              f    Susan       Warner                9
# 1430  983964608              e   Latino     Canadian                1
# 1431   99003721              f    Maria          NaN                1
# 1432  991799581              f   Kavita  Chintapalli                1
# 1433   99571194              f  Rebecca       Garcia                1
#
#       Name_Cluster_500  Name_Cluster_1000  SurName_Cluster_50  \
# 1429                46                224                   2
# 1430                 3                645                   2
# 1431                57                  2                   1
# 1432                 3                729                   2
# 1433                56                161                  42
#
#       SurName_Cluster_500  SurName_Cluster_1000
# 1429                    2                   365
# 1430                  413                   381
# ...

# %%
del df['Name_Cluster']

# %%
df.to_csv("/Users/rajathanda/Downloads/Clust1_Eng.csv", sep=',', encoding='utf-8')
